# %%
print("Hello world")
# Out:
# Hello world

# %%
import os

cpu_num = os.cpu_count()
print(f"My computer has {cpu_num} CPUs")
# Out:
# My computer has 8 CPUs

# %%
# !python cpus.py
# Out:
# python: can't open file 'C:\\Users\\coope\\cpus.py': [Errno 2] No such file or directory
